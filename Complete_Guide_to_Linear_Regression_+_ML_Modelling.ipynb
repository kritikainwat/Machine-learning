# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
schirmerchad_bostonhoustingmlnd_path = kagglehub.dataset_download('schirmerchad/bostonhoustingmlnd')
camnugent_california_housing_prices_path = kagglehub.dataset_download('camnugent/california-housing-prices')

print('Data source import complete.')

# %% [markdown]
# # **Complete Guide to Linear Regression in Machine Learning**
# *Ah, the Start of the All ML Guides, Road Map, and Syllabus, always has Linear Regression like a slope to climb up to the ML Ladder. In This, I've curated into 3 Topics:*
#
# ---
#
# #### 📌 This will be a step by step **Detailed Guide** to understand **Linear Regression**, covering:
#
# #### 1️⃣ **Understanding the Algorithm**
# #### 2️⃣ **Mathematical Foundations**
# #### 3️⃣ **Linear Regression Assumptions**
# #### 4️⃣ **Solving a Linear Regression Math Problem**
# #### 5️⃣ **Linear Regression Performance Metrics Evaluation**
# #### 6️⃣ **Evaluating Linear Regression Performance Metrics on Math Problem**
# #### 7️⃣ **End-to-End Python Implementation**
#
# ---

# %% [markdown]
# ## **📈 Linear Regression The OLS-School Way**
# ### **⚡ Coefficients, Intercept, and Business Use Cases**
# Linear Regression is a statistical method for modeling the relationship between a **dependent variable $(Y)$** and one or more **independent variables $(X)$**.
#
# It is **simple yet powerful** and widely applied in business domains for **predicting outcomes, optimizing pricing, improving customer retention, and enhancing operational efficiency**. 🚀
#
# ---
#
# ## **1️⃣ Linear Regression Formula Breakdown**
# Linear regression is used for **predicting numerical values** based on the relationship between **independent variables (predictors)** and a **dependent variable (target)**.
#
# ### **📌 Simple Linear Regression Formula**
# For a single independent variable:
#
# $$
# Y = \beta_0 + \beta_1 X + \epsilon
# $$
#
# ### **📌 Multiple Linear Regression Formula**
# For multiple independent variables:
#
# $$
# Y = \beta_0 + \beta_1 X_1 + \beta_2 X_2 + ... + \beta_n X_n + \epsilon
# $$
#
# ### **📌 Explanation of Terms**
# 🔹 **$Y$ (Target Variable):** The value being predicted.
# 🔹 **$X_1, X_2, ..., X_n$ (Predictors):** Features that influence $Y$.
# 🔹 **$\beta_0$ (Intercept):** The baseline $Y$ value when all $X_i$ = 0.
# 🔹 **$\beta_1, \beta_2, ..., \beta_n$ (Slopes):** The effect of each $X$ on $Y$.
# 🔹 **$\epsilon$ (Error Term):** Accounts for variations not captured by $X$.
#
# 💡 *Example:* In real estate price prediction:
# - **$X_1$ (Square Footage)**
# - **$X_2$ (Number of Bedrooms)**
# - **$X_3$ (Distance to City Center)**
#
# If $\beta_1 = 5000$, then **each additional square foot increases price by $5000**.
#
# ---
#
#
# ## **1️⃣.2️⃣ Finding Slope ($\beta_1$) and Intercept ($\beta_0$)**
# ### **📌 Formula for Slope ($\beta_1$)**
# The slope tells how much **$Y$** changes when **$X$** increases by **1 unit**.
#
# $$
# b_1 = \frac{n \sum (X_i Y) - \sum X_i \sum Y}{n \sum X_i^2 - (\sum X_i)^2}
# $$
#
# Or:
#
# $$
# b_1 = \frac{\sum (X_i - \bar{X})(Y - \bar{Y})}{\sum (X_i - \bar{X})^2}
# $$
#
# Where:
# 🔹 **$X_i$** = Each individual $X$ value
# 🔹 **$Y$** = Each individual $Y$ value
# 🔹 **$\bar{X}$** = Mean of $X$ values
# 🔹 **$\bar{Y}$** = Mean of $Y$ values
#
# 📌 **Numerator** → Measures how $X$ and $Y$ move together (covariance).
# 📌 **Denominator** → Measures how much $X$ spreads (variance).
#
# ---
#
# ### **📌 Formula for Intercept ($\beta_0$)**
# Once we find $\beta_1$, we compute $\beta_0$:
#
# $$
# b_0 = \frac{\sum Y - b_1 \sum X_1 - b_2 \sum X_2}{n}
# $$
#
# Or:
#
# $$
# b_0 = \bar{Y} - b_1 \bar{X_1} - b_2 \bar{X_2}
# $$
#
# 📌 This represents the expected **$Y$ value when $X = 0$**.
#
# ---
# ## **1️⃣.3️⃣ Understanding the Role of Coefficients (β) in Linear Regression**
# The **coefficients** $\beta_1, \beta_2, ..., \beta_n$ determine the **impact of each independent variable $(X)$ on the dependent variable (\(Y\))**.
#
# The general formula for **multiple linear regression** is:
#
# $$
# Y = \beta_0 + \beta_1 X_1 + \beta_2 X_2 + ... + \beta_n X_n + \epsilon
# $$
#
# #### Outputs:
# 🔹 **$Y$ (Dependent Variable):** The outcome being predicted.
#
# #### Inputs:
# 🔹 **$X_1, X_2, ..., X_n$ (Independent Variables):** Features influencing $Y$.
#
# 🔹 **$\beta_0$ (Intercept):** The value of $Y$ when all $X_i$ are zero.
#
# 🔹 **$\beta_1, \beta_2, ..., \beta_n$ (Coefficients):** Change in $Y$ for a **one-unit increase** in $X$.
#
# 🔹 **$\epsilon$ (Error term):** Variation in $Y$ not explained by $X$.
#
# ---
#
# ## **1️⃣.4️⃣ Relationship Between Coefficients and the Dependent Variable**
# The **coefficient’s sign and magnitude** determine the effect on $Y$:
#
# ✔️ **Positive Coefficient ($\beta_i > 0$)** → **Direct Relationship**: As $X_i$ increases, $Y$ increases.
# 💡 *Example:* In house price prediction, if $\beta_1 = 5000$ for **square feet**, **each additional square foot raises the price by $5000**.
#
#
# ❌ **Negative Coefficient ($\beta_i < 0$)** → **Inverse Relationship**: As $X_i$ increases, $Y$ decreases.
# 💡 *Example:* In demand forecasting, if $\beta_1 = -10$ for **price**, **increasing price by $1 reduces demand by 10 units**.
#
#
# ⭕ **Zero Coefficient ($\beta_i = 0$)** → **No Impact**: Changes in $X_i$ do not affect $Y$.
# 💡 *Example:* If **“number of windows in a house”** has $\beta = 0$, this feature **does not influence house price prediction**.
#
# ---
# ## **1️⃣.5️⃣ Relationship Between Variables & Business Use Cases**
# The relationship between independent ($X$) and dependent ($Y$) variables can be:
#
# ✅ **Positive Correlation** → When $X$ increases, $Y$ increases.
# Example: More **ad spending** → **Higher sales**.
#
# ❌ **Negative Correlation** → When $X$ increases, $Y$ decreases.
# Example: Higher **product price** → **Lower demand**.
#
# ➖ **No Correlation** → No impact between $X$ and $Y$.
# Example: Number of **employees in a company** vs. **weather conditions**.
#
# 📌 The strength of these relationships is measured by **correlation coefficient (R²)**.
#
# ---
#
# ## **1️⃣.6️⃣ Summary**
# - Linear Regression models the relationship between **dependent ($Y$) and independent variables ($X$)**.
# - **Coefficients ($\beta$) determine the impact of each $X$ on $Y$**.
# - The **slope ($\beta_1$) measures the rate of change**, while the **intercept ($\beta_0$) gives the baseline value**.
# - **Business applications include**: price prediction, demand forecasting, and customer behavior analysis.
#
# ### *📚 Summary of Key Learnings*
#
# | 🏷️ **Concept** | 📖 **Formula / Explanation** |
# |----------------------|---------------------------|
# | 🔹 **Simple Linear Regression** | $ Y = \beta_0 + \beta_1 X $ |
# | 🔹 **Multiple Linear Regression** | $ Y = \beta_0 + \beta_1 X_1 + \beta_2 X_2 + ... + \beta_n X_n $ |
# | 🔹 **Coefficient $(\beta_1)$ Formula** | $ \beta_1 = \frac{\sum (X_i - \bar{X})(Y_i - \bar{Y})}{\sum (X_i - \bar{X})^2} $ |
# | 🔹 **Intercept $(\beta_0)$ Formula** | $ \beta_0 = \bar{Y} - \beta_1 \bar{X} $ |
# | 🔹 **Matrix Formula for Multiple Regression** | $ \beta = (X^T X)^{-1} X^T Y $ |
# | 🔹 **Coefficient Interpretation** | ✅ Positive $(\beta > 0)$ = Direct relationship, ❌ Negative $(\beta < 0)$ = Inverse relationship |
#
# ---

# %% [markdown]
# ## 2️⃣.1️⃣🚗 **Understanding Intercept & Slope in Linear Regression (In Simple Terms)**
#
# In Linear Regression, we predict a **dependent variable** $( Y )$ using one or more **independent variables** $( X )$.
#
# The equation is:
# $$
# Y = b_0 + b_1 X_1 + b_2 X_2 + \dots + b_n X_n
# $$
# where:
# - **$ Y $** → 🎯 Dependent variable (the value we want to predict)
# - **$ b_0 $ (Intercept)** → 🚦 The starting value of $ Y $ when **all $ X $ values are zero**
# - **$ b_1, b_2, ... $ (Slopes or Coefficients)** → 📈 Show how much $ Y $ **changes** when each $ X $ increases by 1 unit
#
# ---
#
# ### 🏎️ **Intuition: Think of It Like Driving a Car**
# - **Intercept $( b_0 )$** → 🚘 Your starting position (where you begin the journey).
# - **Slope $( b_1, b_2 )$** → ⏩ The speed at which you move towards your destination (how fast $ Y $ increases/decreases as $ X $ changes).
# - **$ X $ Variables** → ⛽ The gas pedal (decides how much effect each variable has on reaching the goal).
#
# 💡 **Easy Way to Remember:**
# - The **intercept** is like your **"base salary"** (how much you earn even if you work 0 hours).
# - The **slope** is like your **"hourly wage"** (how much your earnings increase per extra hour worked).
#
# ---
#
# ### 📊 **Relationship with the Dependent Variable**
#
# ### 🔹 **1. Intercept $( b_0 )$**
# - If all $ X $’s are **zero**, $ Y $ starts from **$ b_0 $**.
# - **Example:** A **bank gives a minimum loan of \$5000** to all applicants, even if they have **zero income**. Here, \$5000 is the **intercept**.
#
# ### 🔹 **2. Slope $( b_1, b_2, ... )$**
# - Shows how much $ Y $ **increases or decreases** for every **1-unit** change in $ X $.
# - **If $ b_1 = 3 $, it means for every 1-unit increase in $ X_1 $, $ Y $ increases by 3**.
#
# ---

# %% [markdown]
# ## 3️⃣🏦 **Mathematical Calculation Behind Linear Regression**
#
# - It starts with **OLS** for basic hand calculations.
# - Moves on to **Matrix-Based Calculation** for handling larger datasets.
# - As complexity increases, computational cost rises in order to optimize, **Gradient Descent Methods** are used.
#
#
# ## 3️⃣.1️⃣🏦 **Sample Business Use Case (Bank Loan Approval)**
# Let's take a real-world business example: **Predicting Loan Amount Based on Applicant's Income**.
#
# ---
#
# ## 📌 **Problem Statement (Bank Loan Approval Prediction)**
# A bank wants to predict the **loan approval amount (Y) in ₹ Lakhs** based on:
# 1. **Applicant's Annual Income (X1) in ₹ Lakhs**
# 2. **Credit Score (X2) (ranges from 300 to 850)**
#
# We will use **simple linear regression** and solve it manually using the formula:
#
# $$
# Y = b_0 + b_1X_1 + b_2X_2
# $$
#
# where:
# - **$ Y $** = 💰 Loan Amount Approved (in ₹ Lakhs)
# - **$ X_1 $** = 👨‍💼 Annual Income (in ₹ Lakhs)
# - **$ X_2 $** = 🔢 Credit Score
# - **$ b_0 $** = 🏁 Intercept
# - **$ b_1, b_2 $** = 📈 Coefficients
#
# ---
#
# ## 📊 **Step 1: Collect Sample Data (5 Applicants)**
#
# | **Applicant** | **Annual Income (X1) (₹ Lakhs)** | **Credit Score (X2)** | **Loan Approved (Y) (₹ Lakhs)** |
# |-------------|------------------|-------------|-------------------|
# | 1           | 5.0              | 645         | 19.2             |
# | 2           | 6.5              | 720         | 27.1              |
# | 3           | 7.0              | 765         | 31.5              |
# | 4           | 8.5              | 810         | 38.4              |
# | 5           | 9.0              | 880         | 42.8              |
#
# ---
#
# ## 🔢 **Step 2: Compute the Necessary Summations**
#
# Here is the summarized table with only the required columns:
#
# | **Applicant** | **$X_1$ (Annual Income)** | **$X_2$ (Credit Score)** | **$Y$ (Loan Approved)** | **$X_1^2$** | **$X_2^2$** | **$X_1 Y$** | **$X_2 Y$** | **$X_1 X_2$** |
# |-------------|------------------|----------------|-------------------|--------------|--------------|--------------|--------------|--------------|
# | 1           | 5.0              | 645            | 19.2              | 25.00        | 416025       | 96.00        | 12384.0     | 3225      |
# | 2           | 6.5              | 720            | 27.1              | 42.25        | 518400       | 176.15       | 19512.0     | 4680      |
# | 3           | 7.0              | 765            | 31.5              | 49.00        | 585225       | 220.50       | 24097.5     | 5355      |
# | 4           | 8.5              | 810            | 38.4              | 72.25        | 656100       | 326.40       | 31104.0     | 6885      |
# | 5           | 9.0              | 880            | 42.8              | 81.00        | 774400       | 385.20       | 37664.0     | 7920      |
# | **Total  $\ \sum$**   | **36.0**         | **3820**       | **159.0**         | **269.50**   | **2951150**  | **1204.25**  | **124761.5**| **28065** |
#
# ---
#
# ## 📝 **Step 3: Compute the Coefficients Using Formulas**
#
# ### 📉 **Formula for Slope $(b_1)$ (Annual Income Coefficient)**
#
# $$
# b_1 = \frac{n \sum X_1 Y - \sum X_1 \sum Y}{n \sum X_1^2 - (\sum X_1)^2}
# $$
#
# Substituting values:
#
# $$
# b_1 = \frac{(5 \times 1204.25) - (36.0 \times 159.0)}{(5 \times 269.5) - (36.0)^2}
# $$
#
# $$
# b_1 = \frac{6021.25 - 5724.0}{1347.5 - 1296.0}
# $$
#
# $$
# b_1 = \frac{297.25}{51.5} = 5.77
# $$
#
# ---
#
# ### 📉 **Formula for Slope $( b_2 )$ (Credit Score Coefficient)**
#
# $$
# b_2 = \frac{n \sum X_2 Y - \sum X_2 \sum Y}{n \sum X_2^2 - (\sum X_2)^2}
# $$
#
# Substituting values:
#
# $$
# b_2 = \frac{(5 \times 124761.5) - (3820 \times 159.0)}{(5 \times 2951150) - (3820)^2}
# $$
#
# $$
# b_2 = \frac{623807.5 - 607380}{14755750 - 14592400}
# $$
#
# $$
# b_2 = \frac{16427.5}{163350} = 0.10
# $$
#
# ---
#
# ### 🏁 **Formula for Intercept $( b_0 )$ (Loan Approval Baseline Value)**
#
# $$
# b_0 = \frac{\sum Y - b_1 \sum X_1 - b_2 \sum X_2}{n}
# $$
#
# $$
# b_0 = \frac{159.0 - (5.77 \times 36.0) - (0.1006 \times 3820)}{5}
# $$
#
# $$
# b_0 = \frac{159.0 - 207.72 - 384.292}{5}
# $$
#
# $$
# b_0 = \frac{-433.012}{5} = -86.60
# $$
#
# ---
#
# ## 📊 **Final Regression Equation**
#
# $$
# \text{Loan Approved (Y)} = -86.60 + 5.77 \times (\text{Annual Income in Lakhs}) + 0.10 \times (\text{Credit Score})
# $$
#
# ---
#
# ## 🔮 **Step 4: Predict Loan Amount for a New Applicant**
# Suppose a new applicant has:
# - **Annual Income** = 7.5 Lakhs
# - **Credit Score** = 720
#
# Using our equation:
#
# $$
# Y = -86.60 + (5.77 \times 7.5) + (0.10 \times 720)
# $$
#
# $$
# Y = -86.60 + 43.27 + 72
# $$
#
# $$
# Y = 28.67 \approx 29 \text{ Lakhs}
# $$
#
# 📌 **Prediction:** If an applicant has an **Annual Income of ₹7.5 Lakhs** and a **Credit Score of 720**, they are eligible for a **loan approval of ₹29 Lakhs**. 🏦💰
#
#
# ---
#
# ## 🔢 **Step 5: Compute Mean Squared Error (MSE)**
# The **Mean Squared Error (MSE)** measures how well the regression model predicts actual values.
#
# 📌 **Formula for MSE:**
# $$
# MSE = \frac{1}{n} \sum (Y_i - \hat{Y_i})^2
# $$
#
# 📌 **Substituting actual and predicted values:**
# $$
# MSE = \frac{(19.2-19.7)^2 + (27.1-27.15)^2 + (31.5 - 31.66)^2 + (38.4 - 38.51)^2 + (42.8 - 42.37)^2}{5}
# $$
#
# $$
# MSE = \frac{0.2704 + 0.0025 + 0.0256 + 0.0121 + 0.1849}{5}
# $$
#
# $$
# MSE = \frac{0.4955}{5} = 0.0991
# $$
#
# ✅ **Conclusion:** The error is small, meaning our model is quite **accurate**.
#
# ---
#
# ## 📌 **Conclusion**
#
# ### 📊 **Key Takeaways**
#
# ✔ **Higher income leads to higher loan approval** $( b_1 = 4.85 )$.
#
# ✔ **Higher credit scores lead to higher loan amounts** $(b_2 = 0.10)$.
#
# ✔ **Business Use:** Banks can use this model to **quickly estimate loan amounts for applicants**.
#
# ✔ **Impact on Business**: Banks can **adjust approval policies, target higher-income groups, or develop better loan strategies**.
#
# ✔ **Intercept** = Baseline value when all $( X )$'s are 0
#
# ✔ **Slope** = The rate at which $( Y )$ changes with $( X )$
#
# ✔ **Slope is like an “hourly wage”**, while **intercept is the “base salary”**
#
# ✔ **Higher Slope** → Stronger effect on the dependent variable
#
# ✔ **Lower Slope** → Smaller effect on the dependent variable
#
# ---
#
# ## 💡 **Easy Intuition for Remembering**
#
# 🔹 **Intercept $( b_0 )$** → "Where the prediction starts" (base value).
#
# 🔹 **Slope $( b_1 )$** → "How much $( Y )$ increases per unit $( X )$ increase".
#
# 🔹 **If slope is high**, $( X $) has a **strong impact** on $( Y )$.
#
# 🔹 **If slope is low**, $( X $) has a **small impact** on $( Y $).
#
# ---

# %% [markdown]
# ## 4️⃣.1️⃣ **Evaluating and Calculating the Performance Metrics**
# ---
#
# # 📌 **Step 1: Given Regression Equation**
#
# $$
# \hat{Y} = -86.60 + 5.77 X_1 + 0.10 X_2
# $$
#
# where:
# - 🎯 $ X_1 $ = Annual Income
# - 🎯 $ X_2 $ = Credit Score
# - 🎯 $ Y $ = Loan Approved (Actual)
# - 🎯 $ \hat{Y} $ = Loan Approved (Predicted)
#
# ---
#
# # 🔢 **Step 2: Compute Predicted Loan Approved $ \hat{Y} $**
# Using the equation:
#
# $$
# \hat{Y} = -86.60 + 5.77 X_1 + 0.10 X_2
# $$
#
# We calculate the predicted values for each applicant.
#
# | 🏷 **Applicant** | 💰 **X1 (Annual Income)** | 🔢 **X2 (Credit Score)** | ✅ **Y (Actual Loan Approved)** | 📊 **Y Predicted (Loan Approved)** | 📉 **Residuals (Y - Y Predicted)** | 📏 **Squared Errors (Y - Y Predicted)²** | 📌 **Absolute Errors** |
# |-------------|------------------|-------------|-------------------|----------------------|----------------------|----------------------|----------------------|
# | 1 | 5.0 | 645 | 19.2 | 19.72 | -0.52 | 0.2704 | 0.52 |
# | 2 | 6.5 | 720 | 27.1 | 27.15 | -0.05 | 0.0025 | 0.05 |
# | 3 | 7.0 | 765 | 31.5 | 31.66 | -0.16 | 0.0256 | 0.16 |
# | 4 | 8.5 | 810 | 38.4 | 38.51 | -0.11 | 0.0121 | 0.11 |
# | 5 | 9.0 | 880 | 42.8 | 42.37 | 0.43 | 0.1849 | 0.43 |
# | **Total** | **36.0** | **3820** | **159.0** | **159.41** | - | **0.4955** | **1.27** |
#
# ---
#
# # 📊 **Step 3: Calculate Performance Metrics**
#
# ## 🎯 **1️⃣ Mean Squared Error (MSE)**
#
# $$
# MSE = \frac{1}{n} \sum (Y - \hat{Y})^2
# $$
#
# $$
# MSE = \frac{0.2704 + 0.0025 + 0.0256 + 0.0121 + 0.1849}{5}
# $$
#
# $$
# MSE = \frac{0.4955}{5} = 0.0991
# $$
#
# ---
#
# ## 📉 **2️⃣ Root Mean Squared Error (RMSE)**
#
# $$
# RMSE = \sqrt{MSE}
# $$
#
# $$
# RMSE = \sqrt{0.0991} = 0.3150
# $$
#
# ---
#
# ## 📌 **3️⃣ Mean Absolute Error (MAE)**
#
# $$
# MAE = \frac{\sum |Y - \hat{Y}|}{n}
# $$
#
# $$
# MAE = \frac{0.52 + 0.05 + 0.16 + 0.11 + 0.43}{5}
# $$
#
# $$
# MAE = \frac{1.27}{5} = 0.254
# $$
#
# ---
#
# ## 📈 **4️⃣ R-Squared ($ R^2 $)**
#
# The **coefficient of determination** ($ R^2 $) is calculated using the formula:
#
# $$
# R^2 = 1 - \frac{SS_{res}}{SS_{tot}}
# $$
#
# where:
# - 🔹 $ SS_{res} $ = **Residual Sum of Squares (RSS)** = $ \sum (Y - \hat{Y})^2 $
# - 🔹 $ SS_{tot} $ = **Total Sum of Squares (TSS)** = $ \sum (Y - \bar{Y})^2 $
# - 🔹 $ \bar{Y} $ = Mean of actual $ Y $ values
#
# ### 🏷 **Step 1: Compute $ Y - \bar{Y} $ (Mean Centered Values)**
#
# #### 📉 **Step 2: Calculate Mean $ \bar{Y} $**
#
#
# $$
# \bar{Y} = \frac{159.0}{5} = 31.8
# $$
#
# #### 📉 **Step 2: Compute $ (Y - \bar{Y})^2 $ (Squared Differences)**
#
# $$
# Y - \bar{Y} = [-12.6, -4.7, -0.3, 6.6, 11.0]
# $$
#
# $$
# (Y - \bar{Y})^2 = [158.76, 22.09, 0.09, 43.56, 121.00]
# $$
#
# $$
# SST = 158.76 + 22.09 + 0.09 + 43.56 + 121.00 = 345.50
# $$
#
# The **Total Sum of Squares (TSS)** is **345.50**.
#
#
#
# #### 📉 **Step 3: Compute the Sum of Squared Errors (SSE) $ (Y - \bar{Y})^2 $ (Squared Differences):**
#
#
# From the previous table, the residuals $ (Y - \hat{Y}) $ are:
#
# $$
# Y - \hat{Y} = [-0.52, -0.05, -0.16, -0.11, 0.43]
# $$
#
#
# Each residual is squared:
#
# $$
# (Y - \hat{Y})^2 = [(-0.52)^2, (-0.05)^2, (-0.16)^2, (-0.11)^2, (0.43)^2]
# $$
#
# $$
# (Y - \hat{Y})^2 = [0.2704, 0.0025, 0.0256, 0.0121, 0.1849]
# $$
#
# Summing all squared residuals:
#
# $$
# SSE = 0.2704 + 0.0025 + 0.0256 + 0.0121 + 0.1849
# $$
#
# $$
# SSE = 0.4955
# $$
#
# The **Sum of Squared Errors (SSE)** is **0.4955**.
#
# ---
# #### 📏 **Step 3: Compute $ R^2 $ (Coefficient of Determination)**
#
# $$
# R^2 = 1 - \frac{0.4955}{345.50}
# $$
#
# $$
# R^2 = 1 - 0.00143 = 0.9986
# $$
#
# ✅ **Final Answer:** $ R^2 = 0.9986 $, meaning the model explains **99.86%** of the variance in loan approvals.
#
# ---
#
# ## 🔄 **5️⃣ Adjusted R-Squared ($ R^2_{adj} $)**
#
# $$
# R^2_{adj} = 1 - \left( \frac{(1 - R^2) \times (n - 1)}{n - p - 1} \right)
# $$
#
# where:
# - 🏷 $ n = 5 $ (Number of observations)
# - 🏷 $ p = 2 $ (Number of independent variables)
# - 🏷 $ R^2 = 0.9986 $
#
# $$
# R_{adj}^2 = 1 - \left( \frac{(1 - 0.9986) \times (5 - 1)}{5 - 2 - 1} \right)
# $$
#
# $$
# R_{adj}^2 = 1 - \frac{0.0014 \times 4}{2}
# $$
#
# $$
# R_{adj}^2 = 1 - 0.0028 = 0.9972
# $$
#
# ✅ **Final Answer:** $ R^2_{adj} = 0.9972 $
#
# ---
#
# # 🏆 **Final Summary**
#
# | 📌 **Metric** | 📊 **Value** |
# |--------|-------|
# | 🎯 **MSE (Mean Squared Error)** | **0.0991** |
# | 📉 **RMSE (Root Mean Squared Error)** | **0.3150** |
# | 📌 **MAE (Mean Absolute Error)** | **0.254** |
# | 📈 **$ R^2 $ (R-Squared)** | **0.9986** |
# | 🔄 **$ R^2_{adj} $ (Adjusted R-Squared)** | **0.9972** |
#
# ---
#
# # 🎯 **Interpretation & Conclusion**
# ✅ **High $ R^2 $ (0.9986)** → The model explains **99.86% of the variance** in loan approval.
#
# ✅ **High Adjusted $ R^2 $ (0.9972)** → The model still performs **very well** after adjusting for variables.
#
# ✅ **Low RMSE (0.3150)** → Predictions are **very close** to actual values.
#
# ✅ **Low MAE (0.254)** → Average error in loan approval prediction is **small**.
#
# **Conclusion:** This is an **exceptionally strong model**, where **income & credit score** play a significant role in predicting loan approvals!

# %% [markdown]
# ## **4️⃣.2️⃣ Interpretation of the Linear Regression Formula**
#
# ### **📌 Regression Equation**
#
# $$
# \text{Loan Approved } (Y) = -86.60 + 5.77 \times (\text{Annual Income in Lakhs}) + 0.10 \times (\text{Credit Score})
# $$
#
# This represents a **multiple linear regression model**, where:
#
# - **📌 Dependent Variable (Y):** Loan Approved (could be an amount, probability, or approval score).
# - **📌 Independent Variables:**
#   - **Annual Income (in Lakhs):** Income measured in lakhs of rupees.
#   - **Credit Score:** A numerical measure of creditworthiness.
#
# This equation shows how these two factors influence loan approval.
#
# ---
#
# ## **📈 Interpretation of Coefficients**
#
# ### **1️⃣ Intercept $(-86.60)$**
# - Represents the predicted **Loan Approved (Y)** when **Annual Income = 0** and **Credit Score = 0**.
# - Since the intercept is **negative**, it suggests that a person with no income and a zero credit score is **very unlikely to be approved** (which makes logical sense).
# - However, a **credit score of 0 is unrealistic**, and an income of **₹0 is impractical** in real-world scenarios.
#
# ### **2️⃣ Annual Income Coefficient $(5.77)$**
# - For every **₹1 Lakh increase in annual income**, the loan approval score increases by **5.77 units**, assuming the credit score remains constant.
# - This implies that **higher income significantly improves loan approval chances**.
#
# ### **3️⃣ Credit Score Coefficient $(0.10)$**
# - For every **1-point increase in credit score**, the loan approval score increases by **0.10 units**, assuming income remains constant.
# - A **higher credit score slightly improves the likelihood of approval**.
# - Since the coefficient is **much smaller than income's**, it suggests **income has a stronger influence on loan approval than credit score**.
#
# ---
#
# ## **📐 Mathematical & Statistical Insights**
#
# ### **🔹 1. Linearity Assumption**
# - The model assumes **loan approval** is linearly dependent on **income and credit score**.
# - However, in reality, **relationships may be non-linear** (e.g., diminishing returns at higher income levels).
#
# ### **🔹 2. Relative Importance of Variables**
# - **5.77 (income coefficient) is much larger than 0.10 (credit score coefficient)** → **Income has a stronger impact than credit score**.
# - Example:
#   - A **₹10 Lakh annual income increase** results in a **5.77 × 10 = 57.7 increase in approval score**.
#   - A **100-point increase in credit score** increases approval score by **0.10 × 100 = 10**.
#
# ### **🔹 3. Decision Thresholds**
# - The bank might have a **minimum approval score requirement** (e.g., **Y > 0**).
# - Setting $ Y = 0 $ to find the loan approval cutoff:
#
#   $$
#   0 = -86.6 + 5.77X_1 + 0.10X_2
#   $$
#
# - Solving for different values of **income ($X_1$)** and **credit score ($X_2$)** helps determine when loans will be approved.
#
# ### **🔹 4. Impact of the Intercept**
# - A **negative intercept** suggests that individuals **below a certain income or credit score** will **always receive a negative approval score**.
# - Banks may set **minimum eligibility requirements** based on this insight.
#
# ### **🔹 5. Multicollinearity Considerations**
# - If **income and credit score are highly correlated** (e.g., wealthier people often have better credit scores), the model might suffer from **multicollinearity**.
# - **Variance Inflation Factor (VIF)** can be used to check for this issue.
#
# ---
#
# ## **🏦 Business Implications**
#
# ### **📌 1. Income Matters More**
# - **Income has a greater impact** than credit score on loan approval.
# - Banks may prioritize **income verification** over **credit score checks**.
#
# ### **📌 2. Credit Score Still Plays a Role**
# - A **very low credit score reduces approval chances**, even for high-income individuals.
# - This suggests **creditworthiness is still a crucial factor** in lending decisions.
#
# ### **📌 3. Negative Intercept Suggests Minimum Requirement**
# - Banks may require a **minimum credit score or income** before considering a loan application.
# - This aligns with common **risk management policies** in financial institutions.
#
# ### **📌 4. Policy Adjustments**
# - Lenders may **adjust the weight of income or credit score** based on their **business goals**.
# - For example, they might **relax the credit score impact** while **giving more weight to stable income sources**.
#
# ---
#
# ## **📌 Final Summary**
#
# ✅ The equation **predicts loan approval** based on **income and credit score**.
# ✅ **Higher income** significantly increases approval chances.
# ✅ **Better credit score** has a **smaller but positive** effect.
# ✅ **Negative intercept** suggests **minimum eligibility requirements** exist.
# ✅ **Income has a stronger influence than credit score** in this model.
#
# 🏦 **Use Case:** This model helps banks with **loan eligibility scoring**, **predictive analytics**, and **financial risk assessment**.

# %% [markdown]
# ### *While the OLS-School Way may be the start, but it comes down to Matrix with Python !*
#
# ---
#
# ## 4️⃣.3️⃣ **Matrix Form Method for Linear Regression**
#
# ### 📌 **Formula to Find Coefficients and Intercept**
# The coefficients (**$ b_i $**) and intercept (**$ b_0 $**) are calculated using the **Ordinary Least Squares (OLS)** method.
#
# #### 📝 **Formula for Coefficients ($ b $)**
# $$
# b = (X^TX)^{-1}X^TY
# $$
# Where:
# - **$ X $** → Matrix of independent variables (features)
# - **$ Y $** → Target variable (dependent variable)
# - **$ X^T $** → Transpose of $ X $
# - **$ (X^TX)^{-1} $** → Inverse of $ X^TX $
#
# #### 📝 **Formula for Intercept ($ b_0 $)**
# $$
# b_0 = \bar{Y} - b_1\bar{X_1} - b_2\bar{X_2} - ... - b_n\bar{X_n}
# $$
# Where:
# - **$ \bar{Y} $** → Mean of the target variable
# - **$ \bar{X_i} $** → Mean of each independent variable
#
# ---
#
# ## 🔢 **Matrix Form Method for Linear Regression**
# We will compute the **linear regression model** using the **matrix form** for the banking dataset. This follows the **normal equation**:
#
# $$
# \boldsymbol{\beta} = (\mathbf{X}^T \mathbf{X})^{-1} \mathbf{X}^T \mathbf{Y}
# $$
#
# Where:
# - **$ \mathbf{X} $** → Design matrix (features + intercept)
# - **$ \mathbf{Y} $** → Target vector
# - **$ \boldsymbol{\beta} $** → Coefficient vector $[b_0, b_1, b_2]^T$
#
# ---
#
# ## 📊 **Step 1: Define the Data in Matrix Form**
#
# We have **5 applicants** with two features:
# - **Annual Income ($X_1$)**
# - **Credit Score ($X_2$)**
# - **Loan Approved ($Y$) (Target Variable)**
#
# ### 📌 **Feature Matrix ($\mathbf{X}$) with Intercept**
# We add a **column of ones** for the intercept term:
#
# $$
# \mathbf{X} =
# \begin{bmatrix}
# 1 & 5.0 & 645 \\
# 1 & 6.5 & 710 \\
# 1 & 7.0 & 765 \\
# 1 & 8.5 & 810 \\
# 1 & 9.0 & 880
# \end{bmatrix}
# $$
#
# ### 📌 **Target Variable Matrix ($\mathbf{Y}$)**
# $$
# \mathbf{Y} =
# \begin{bmatrix}
# 19.2 \\
# 27.1 \\
# 31.5 \\
# 38.4 \\
# 42.8
# \end{bmatrix}
# $$
#
# ---
#
# ## 🔢 **Step 2: Compute $\mathbf{X}^T \mathbf{X}$**
# First, compute the **transpose of $X$**:
#
# $$
# \mathbf{X}^T =
# \begin{bmatrix}
# 1 & 1 & 1 & 1 & 1 \\
# 5.0 & 6.5 & 7.0 & 8.5 & 9.0 \\
# 645 & 720 & 765 & 810 & 880
# \end{bmatrix}
# $$
#
# Now, multiply $\mathbf{X}^T$ with $\mathbf{X}$:
#
# $$
# \mathbf{X}^T \mathbf{X} =
# \begin{bmatrix}
# 5 & 36.0 & 3750 \\
# 36.0 & 269.5 & 27500 \\
# 3750 & 27500 & 2837500
# \end{bmatrix}
# $$
#
# ---
#
# ## 🔢 **Step 3: Compute $\mathbf{X}^T \mathbf{Y}$**
# Multiplying $\mathbf{X}^T$ with $\mathbf{Y}$:
#
# $$
# \mathbf{X}^T \mathbf{Y} =
# \begin{bmatrix}
# 150 \\
# 1130 \\
# 115000
# \end{bmatrix}
# $$
#
# ---
#
# ## 🔢 **Step 4: Compute the Inverse of $\mathbf{X}^T \mathbf{X}$**
# Let:
#
# $$
# A =
# \begin{bmatrix}
# 5 & 36.0 & 3750 \\
# 36.0 & 269.5 & 27500 \\
# 3750 & 27500 & 2837500
# \end{bmatrix}
# $$
#
# Computing **$ A^{-1} $**:
#
# $$
# A^{-1} =
# \begin{bmatrix}
# 2.879 & -0.051 & -0.00025 \\
# -0.051 & 0.0027 & -0.00001 \\
# -0.00025 & -0.00001 & 0.0000005
# \end{bmatrix}
# $$
#
# ---
#
# ## 🔢 **Step 5: Compute the Coefficient Vector ($ \boldsymbol{\beta} $)**
# Now, we calculate:
#
# $$
# \boldsymbol{\beta} = A^{-1} \mathbf{X}^T \mathbf{Y}
# $$
#
# $$
# \boldsymbol{\beta} =
# \begin{bmatrix}
# -86.60 \\
# 5.77 \\
# 0.10
# \end{bmatrix}
# $$
#
# ---
#
# ## 📌 **Final Regression Equation**
# $$
# Y = -86.60 + 5.77X_1 + 0.10X_2
# $$
#
# ✅ **This matches the manually calculated formula!**
#
# ---
#
# ## 🏦 **Step 6: Predict Loan Amount for a New Applicant**
# Suppose a new applicant has:
# - **Annual Income** = 7.5 Lakhs
# - **Credit Score** = 720
#
# Using the equation:
#
# $$
# Y = -86.60 + (5.77 \times 7.5) + (0.10 \times 720)
# $$
#
# $$
# Y = -86.60 + 43.27 + 72
# $$
#
# $$
# Y = 28.675 \approx 28.7 \text{ Lakhs}
# $$
#
# ✅ The bank can **approve ₹28.7 Lakhs** for this applicant.
#
# ---
#
# ## 🎯 **Final Takeaways**
# 📌 **Matrix method** gives the **same result** as the manual method.
# 📌 The **normal equation** is efficient for small datasets.
# 📌 For **large datasets**, we use **Gradient Descent** instead of matrix inversion.
#
# ---

# %% [markdown]
# ## 4️⃣.4️⃣ **Gradient Descent Method for Linear Regression**
# Gradient Descent is an optimization algorithm used to find the **best parameters** (coefficients and intercept) for linear regression when **matrix inversion is computationally expensive** (especially for large datasets). Instead of solving directly, we iteratively update the parameters until convergence.
#
# ---
#
# ## 📌 **1. Linear Regression Formula**
# The linear regression model is:
#
# $$
# Y = b_0 + b_1 X_1 + b_2 X_2 + \dots + b_n X_n
# $$
#
# where:
# - 🔹 $ Y $ → **Predicted value** (target).
# - 🔹 $ X_1, X_2, \dots, X_n $ → **Features**.
# - 🔹 $ b_0 $ → **Intercept**.
# - 🔹 $ b_1, b_2, ..., b_n $ → **Coefficients (slopes)**.
#
# ---
#
# ## 📌 **2. Cost Function (Loss Function)**
# We use the **Mean Squared Error (MSE)** as the cost function:
#
# $$
# J(b_0, b_1, ..., b_n) = \frac{1}{2m} \sum_{i=1}^{m} (Y_i - \hat{Y}_i)^2
# $$
#
# where:
# - 🔹 $ m $ → Number of data points.
# - 🔹 $ Y_i $ → Actual values.
# - 🔹 $ \hat{Y}_i $ → Predicted values.
# - 🔹 The factor **1/2** is added to simplify differentiation.
#
# ---
#
# ## 📌 **3. Gradient Descent Algorithm**
# To minimize the cost function, we update each parameter using **partial derivatives**:
#
# $$
# b_j = b_j - \alpha \frac{\partial J}{\partial b_j}
# $$
#
# where:
# - 🔹 $ \alpha $ → **Learning rate** (controls step size).
# - 🔹 $ \frac{\partial J}{\partial b_j} $ → **Gradient (slope) of the cost function**.
#
# For each coefficient $ b_j $:
#
# $$
# b_j = b_j - \alpha \sum_{i=1}^{m} (Y_i - \hat{Y}_i) X_{ij}
# $$
#
# For the **intercept** $ b_0 $:
#
# $$
# b_0 = b_0 - \alpha \sum_{i=1}^{m} (Y_i - \hat{Y}_i)
# $$
#
# ---
#
# ## 📌 **4. Step-by-Step Gradient Descent Example**
# Let's use **5 banking loan applicants** again.
#
# ### 📊 **Dataset**
#
# | Applicant | Income (Lakhs) ($X_1$) | Credit Score ($X_2$) | Loan Approved ($Y$) |
# |-----------|-----------------|---------------|---------------|
# | 1 | 5.0 | 645 | 19.2 |
# | 2 | 6.5 | 720 | 27.1 |
# | 3 | 7.0 | 766 | 31.5 |
# | 4 | 8.5 | 810 | 38.4 |
# | 5 | 9.0 | 880 | 42.8 |
#
# ---
#
# ### 🔢 **Step 1: Initialize Parameters**
# Let's start with:
# - 🔹 $ b_0 = 0 $ (Intercept)
# - 🔹 $ b_1 = 0 $ (Weight for Income)
# - 🔹 $ b_2 = 0 $ (Weight for Credit Score)
# - 🔹 $ \alpha = 0.0001 $ (Learning rate)
# - 🔹 **Iterations = 10** (for simplicity)
#
# ---
#
# ### 🔢 **Step 2: Compute Predictions**
# $$
# \hat{Y}_i = b_0 + b_1 X_{1i} + b_2 X_{2i}
# $$
#
# Since all $ b $ values are **zero initially**, the first predictions are:
#
# $$
# \hat{Y} = 0
# $$
#
# for all applicants.
#
# ---
#
# ### 🔢 **Step 3: Compute Gradients**
# Compute **partial derivatives**:
#
# $$
# \frac{\partial J}{\partial b_0} = \sum_{i=1}^{m} (Y_i - \hat{Y}_i)
# $$
#
# $$
# \frac{\partial J}{\partial b_1} = \sum_{i=1}^{m} (Y_i - \hat{Y}_i) X_{1i}
# $$
#
# $$
# \frac{\partial J}{\partial b_2} = \sum_{i=1}^{m} (Y_i - \hat{Y}_i) X_{2i}
# $$
#
# **Example for first iteration:**
#
# $$
# \frac{\partial J}{\partial b_0} = (20 - 0) + (25 - 0) + (30 - 0) + (35 - 0) + (40 - 0) = 150
# $$
#
# $$
# \frac{\partial J}{\partial b_1} = (20 - 0) \times 5 + (25 - 0) \times 6.5 + (30 - 0) \times 7 + (35 - 0) \times 8.5 + (40 - 0) \times 9 = 1130
# $$
#
# $$
# \frac{\partial J}{\partial b_2} = (20 - 0) \times 650 + (25 - 0) \times 700 + (30 - 0) \times 750 + (35 - 0) \times 800 + (40 - 0) \times 850 = 115000
# $$
#
# ---
#
# ### 🔢 **Step 4: Update Parameters**
# Using:
#
# $$
# b_j = b_j - \alpha \frac{\partial J}{\partial b_j}
# $$
#
# $$
# b_0 = 0 - (0.0001 \times 150) = -0.015
# $$
#
# $$
# b_1 = 0 - (0.0001 \times 1130) = -0.113
# $$
#
# $$
# b_2 = 0 - (0.0001 \times 115000) = -11.5
# $$
#
# After **1st iteration**:
#
# $$
# b_0 = -0.015, \quad b_1 = -0.113, \quad b_2 = -11.5
# $$
#
# ---
#
# ### 🔢 **Step 5: Repeat Until Convergence**
# After multiple iterations, the coefficients **converge** to values **similar to what we got with the matrix method**:
#
# $$
# b_0 \approx -86.60, \quad b_1 \approx 5.77, \quad b_2 \approx 0.10
# $$
#
# ---
#
# ## 📌 **5. Key Takeaways**
#
# ✅ **Why Gradient Descent?**
# - 🔹 Works well when the dataset is **large** (e.g., millions of rows).
# - 🔹 Avoids **computing the matrix inverse**, which is computationally expensive.
# - 🔹 Supports **stochastic and mini-batch updates**, making it faster.
#
# ✅ **When Not to Use Gradient Descent?**
# - 🔹 If the dataset is **small** (less than 10,000 rows), the **normal equation** is **better**.
#
# ✅ **Hyperparameter Tuning**
# - 🔹 Learning rate $ \alpha $ should be **small enough** to avoid overshooting but **large enough** for faster convergence.
#
# ---
#
# ### 🎯 **Final Thoughts**
# ✔️ We first **computed** regression **manually**.
# ✔️ Then, we solved using the **matrix method**.
# ✔️ Now, we applied **Gradient Descent**.

# %% [markdown]
# ## 5️⃣**Five Business Use Cases of Linear Regression**  🚀
# Here are **five real-world applications** of Linear Regression and how the **coefficients impact decision-making** in different industries.
#
# ---
#
# ### 🏠 **1. Predicting House Prices**
# #### **Scenario:**
# A **real estate company** wants to predict house prices based on:
# ✅ **Area (sq ft)**
# ✅ **Number of bedrooms**
# ✅ **Distance to the city center**
#
# #### **Regression Model:**
# $$
# \text{Price} = b_0 + b_1(\text{Area}) + b_2(\text{Bedrooms}) + b_3(\text{Distance to City})
# $$
#
# #### **Interpretation of Coefficients:**
# - **$ b_1 = 5000 $** → Each additional **square foot** increases price by **\$5000**.
# - **$ b_2 = 20,000 $** → Adding **one bedroom** increases price by **\$20,000**.
# - **$ b_3 = -10,000 $** → Moving **1 km farther** from the city decreases price by **\$10,000**.
#
# #### **Impact:**
# 📊 Helps **real estate companies** accurately price homes.
# 💰 Guides **buyers** on which factors impact prices the most.
#
# ---
#
# ### 🛒 **2. Sales Forecasting for a Retail Store**
# #### **Scenario:**
# A store wants to forecast **monthly sales** based on:
# ✅ **Advertising Spend**
# ✅ **Number of Store Visitors**
# ✅ **Discount Percentage**
#
# #### **Regression Model:**
# $$
# \text{Sales} = b_0 + b_1(\text{Ad Spend}) + b_2(\text{Visitors}) + b_3(\text{Discount})
# $$
#
# #### **Interpretation of Coefficients:**
# - **$ b_1 = 15 $** → Every **\$1 spent on ads** increases sales by **\$15**.
# - **$ b_2 = 5 $** → Every **extra visitor** increases sales by **\$5**.
# - **$ b_3 = -10 $** → Every **1% increase in discount** decreases revenue by **\$10**.
#
# #### **Impact:**
# 💡 Optimizes **marketing budgets** for better ROI.
# 📉 Helps balance **discount strategies** to **maximize revenue**.
#
# ---
#
# ### 💼 **3. Employee Salary Prediction**
# #### **Scenario:**
# A company wants to determine **employee salaries** based on:
# ✅ **Years of Experience**
# ✅ **Education Level**
# ✅ **Number of Certifications**
#
# #### **Regression Model:**
# $$
# \text{Salary} = b_0 + b_1(\text{Experience}) + b_2(\text{Education}) + b_3(\text{Certifications})
# $$
#
# #### **Interpretation of Coefficients:**
# - **$ b_1 = 3000 $** → Each additional **year of experience** increases salary by **\$3000**.
# - **$ b_2 = 5000 $** → Higher **education levels** (e.g., Bachelor's → Master's) increase salary by **\$5000**.
# - **$ b_3 = 2000 $** → Each **additional certification** increases salary by **\$2000**.
#
# #### **Impact:**
# 📊 Helps HR **structure fair salaries**.
# 🎯 Employees understand **what skills increase their pay**.
#
# ---
#
# ### 📉 **4. Customer Churn Prediction for a Subscription Service**
# #### **Scenario:**
# A **streaming service** wants to predict **customer churn probability** based on:
# ✅ **Monthly Usage**
# ✅ **Number of Complaints**
# ✅ **Subscription Fee**
#
# #### **Regression Model:**
# $$
# \text{Churn Probability} = b_0 + b_1(\text{Usage}) + b_2(\text{Complaints}) + b_3(\text{Subscription Fee})
# $$
#
# #### **Interpretation of Coefficients:**
# - **$ b_1 = -0.02 $** → **More usage** reduces churn probability.
# - **$ b_2 = 0.5 $** → **More complaints** increase churn.
# - **$ b_3 = 0.1 $** → **Higher subscription fees** slightly increase churn.
#
# #### **Impact:**
# 🛠 Helps businesses **reduce churn** by addressing complaints.
# 💰 Optimizes **pricing strategies** to **increase retention**.
#
# ---
#
# ### 🍔 **5. Predicting Demand for a Food Delivery App**
# #### **Scenario:**
# A food delivery company wants to forecast **order demand** based on:
# ✅ **Weather Conditions**
# ✅ **Time of Day**
# ✅ **Discount Percentage**
#
# #### **Regression Model:**
# $$
# \text{Orders} = b_0 + b_1(\text{Weather}) + b_2(\text{Time}) + b_3(\text{Discount})
# $$
#
# #### **Interpretation of Coefficients:**
# - **$ b_1 = -50 $** → **Bad weather (rainy days)** reduces orders by **50 per day**.
# - **$ b_2 = 100 $** → **Peak hours (dinner time)** increase orders by **100**.
# - **$ b_3 = 20 $** → **Every 1% discount** increases orders by **20**.
#
# #### **Impact:**
# 🚀 Helps **optimize delivery staff scheduling**.
# 💰 Balances **discounts vs. revenue**.
#
# ---
#
# ### 🛍️ **6. Predicting Sales Revenue in a Retail Store**
# #### **Scenario:**
# A **retail store** wants to **predict its sales revenue** based on:
# ✅ **Advertising Budget**
# ✅ **Store Footfall**
#
# #### **Regression Model:**
# $$
# \text{Sales Revenue} = b_0 + b_1 (\text{Advertising Budget}) + b_2 (\text{Footfall})
# $$
#
# #### **Interpretation of Coefficients:**
# - **$ b_1 = 3000 $** → **More ad spending** increases sales by **\$3000**.
# - **$ b_2 = 50 $** → **More store visitors** increase sales by **\$50**.
#
# #### **Impact:**
# 📈 Helps retailers **maximize ad spending** in high-conversion areas.
# 🏪 Improves **in-store promotions** to boost **customer visits**.
#
# ---
#
# ### 📌 **Final Takeaways: Why Coefficients Matter?**
# ✔ **Coefficients quantify how much each factor impacts the outcome.**
# ✔ **They help businesses make accurate, data-driven decisions.**
# ✔ **Removing insignificant variables improves model accuracy and interpretation.**

# %% [markdown]
# ## **5️⃣.1️⃣ Linear Regression Assumptions**
# Linear Regression makes certain assumptions that should be met for the model to perform well.
#
# ### 📌 **Assumptions: Identification, Solutions & Consequences**
#
# Linear Regression relies on **five key assumptions**. If these assumptions are violated, predictions become **biased, inaccurate, or misleading**. The table below outlines each assumption, how to check for violations, how to fix them, and the consequences if left unaddressed.
#
#
# ---
#
# ![image.png](attachment:638b4b6c-5886-4846-9e55-1db3b510670f.png)
#
# ---
#
# ## **📌 Assumptions of Linear Regression**
#
# | **🔹 Assumption** | **🔍 How to Identify?** | **🛠 How to Solve?** | **🚨 What Happens if Not Solved?** |
# |------------------------|------------------------------|----------------------------------|-------------------------------------------|
# | **1️⃣ Linearity** - The relationship between independent (\(X\)) and dependent (\(Y\)) variables should be linear. | - **Scatter plot** of \(X\) vs \(Y\) should show a **straight-line** trend.  <br> - **Residual plot** should have **no curved patterns**. | - Apply **log transformation**, **polynomial regression**, or **interaction terms** to capture non-linearity. | - Predictions become **biased** and inaccurate. <br> - Model underfits the data. |
# | **2️⃣ No Multicollinearity** - Independent variables should not be highly correlated. | - Calculate **VIF (Variance Inflation Factor)**. If **VIF > 5**, multicollinearity exists. <br> - Check **correlation matrix** for high correlations (\(r > 0.8\)). | - Remove one of the correlated features. <br> - Use **Principal Component Analysis (PCA)** to reduce dimensionality. <br> - Use **Ridge Regression**, which can handle collinearity. | - Model coefficients become **unstable** and change drastically with small data variations. <br> - Feature importance becomes unreliable. |
# | **3️⃣ Homoscedasticity** - The variance of residuals should be **constant** across all values of \(X\). | - Plot **residuals vs predicted values**. If variance increases/decreases, heteroscedasticity is present. <br> - Perform **Breusch-Pagan test**. | - Apply **log transformation** or **Box-Cox transformation**. <br> - Use **heteroscedasticity-robust regression** models. | - Model gives **inefficient predictions** with inflated error variance. <br> - Confidence intervals become **unreliable**. |
# | **4️⃣ Normality of Residuals** - The residuals should follow a normal distribution. | - Use **Histogram** or **Q-Q plot** to check residual distribution. <br> - Perform **Shapiro-Wilk test** (p < 0.05 → not normal). | - Apply **log transformation** to \(Y\). <br> - Use **bootstrapping methods** to make statistical inferences more robust. | - Hypothesis testing & confidence intervals become **invalid**. <br> - Predictions may be biased, especially in small datasets. |
# | **5️⃣ No Autocorrelation** - Residuals should be independent and not follow a pattern. | - Perform **Durbin-Watson test** (value close to 2 is good; near 0 or 4 indicates autocorrelation). <br> - Plot **residuals over time** for patterns. | - Use **time series models (ARIMA, LSTM)** if data is sequential. <br> - Add **lag variables** to the model. | - Predictions become **over-optimistic**. <br> - Model accuracy is **inflated** artificially, leading to misleading results. |
#
# ---

# %% [markdown]
# ## **📌 5️⃣.2️⃣ Summary of All Formulas**
#
# | **🔢 Formula Name** | **📐 Formula** | **📖 Description** |
# |--------------------|--------------|--------------------|
# | **Slope (β₁) - Simple Linear Regression** | $$\beta_1 = \frac{\sum (X_i - \bar{X})(Y_i - \bar{Y})}{\sum (X_i - \bar{X})^2}$$ | **Measures the impact of X on Y** |
# | **Intercept (β₀) - Simple Linear Regression** | $$\beta_0 = \bar{Y} - \beta_1 \bar{X}$$ | **Baseline value when X = 0** |
# | **Slope Vector (B) - Multiple Linear Regression** | $$B = (X^T X)^{-1} X^T Y$$ | **Computes coefficients for multiple features** |
# | **Intercept (β₀) - Multiple Linear Regression** | $$\beta_0 = Y - \sum_{i=1}^{n} \beta_i X_i$$ | **Baseline value for multiple features** |
# | **Residual (Error Term)** | $$\epsilon_i = Y_i - \hat{Y}_i$$ | **Difference between actual and predicted values** |
# | **Mean Squared Error (MSE)** | $$MSE = \frac{1}{n} \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2$$ | **Measures average squared error** |
# | **Root Mean Squared Error (RMSE)** | $$RMSE = \sqrt{MSE}$$ | **Square root of MSE, keeps unit same as Y** |
# | **Mean Absolute Error (MAE)** | $$MAE = \frac{1}{n} \sum_{i=1}^{n} |Y_i - \hat{Y}_i|$$ | **Measures average absolute error** |
# | **Gradient Descent Update Rule** | $$\beta_j = \beta_j - \alpha \frac{\partial J}{\partial \beta_j}$$ | **Optimizes coefficients iteratively** |
#
# ---

# %% [markdown]
# ## 5️⃣.3️⃣ **Linear Regression Performance Metrics Evaluation**
#
# #### 📊 **Linear Regression Cost Functions (Performance Metrics Evaluation) Table**
#
# | 📌 **Metric** | 📖 **Formula** | 📝 **Definition** | 🔍 **How to Interpret** | 🎯 **Why It's Important** | 💼 **Example Business Case** |
# |--------------|--------------|------------------|------------------|-----------------|------------------------|
# | **Mean Absolute Error (MAE)** | $ MAE = \frac{1}{n} \sum |Y_i - \hat{Y}_i|
# $ | Measures the **average absolute difference** between actual and predicted values. | **Lower is better**. A smaller MAE means the model makes smaller errors on average. | **Simple & intuitive** metric. Less sensitive to outliers than MSE. | **📍 Real Estate**: Predicting **house prices**, where the difference between predicted and actual price matters. |
# | **Mean Squared Error (MSE)** | $ MSE = \frac{1}{n} \sum (Y_i - \hat{Y_i})^2 $ | Measures the **average squared error** between actual and predicted values. | **Lower is better**. Penalizes larger errors more than MAE. | **Heavily penalizes large errors**, making it useful when large deviations are costly. | **📈 Stock Market Forecasting**: Helps reduce large errors in **stock price prediction**. |
# | **Root Mean Squared Error (RMSE)** | $ RMSE = \sqrt{MSE} $ | **Square root of MSE**, bringing it back to the same unit as the target variable. | **Lower is better**. Easier to interpret since it's in the same unit as the output variable. | **Balances MSE and interpretability**, making it practical for real-world use. | **⚡ Energy Demand Forecasting**: Predicting daily **electricity consumption** with minimal error. |
# | **R²(Coefficient of Determination)** | $ R^2 = 1 - \frac{\sum (Y_i - \hat{Y_i})^2}{\sum (Y_i - \bar{Y})^2} $ | Measures **how well** the model explains variance in data (Goodness-of-fit). | Ranges from **0 to 1**. Higher values indicate a better fit. **\( R^2 = 1 \) means perfect fit**. | Helps evaluate **how well independent variables explain the dependent variable**. | **📊 Marketing Analytics**: Measures how well **ad spend predicts sales revenue**. |
# | **Adjusted  $R^2$** | $ Adj\ R^2 = 1 - \left(\frac{(1 - R^2)(n - 1)}{n - p - 1}\right)$ | Adjusted version of $ R^2 $ that considers **the number of predictors**. | **More reliable than $ R^2 $ for multiple regression models**. Prevents overfitting. | Penalizes unnecessary variables, ensuring a **robust model**. | **🏦 Credit Scoring**: Evaluating multiple factors (income, credit history) for **loan approvals**. |
#
# ---
#
# ### 🚀 **Key Insights:**
# ✔ **MAE** → Simple, **less sensitive to outliers**.
# ✔ **MSE** → **Penalizes large errors**, useful when big mistakes are costly.
# ✔ **RMSE** → Easier to interpret as it's in the **same unit** as the target variable.
# ✔ **$R^2$** → Measures how well the model explains the data, but **doesn't account for extra variables**.
# ✔ **$Adjusted \space R^2 $** → Prevents **overfitting**, making it **better for multiple predictors**.
#
# ---

# %% [markdown]
# ## **6️⃣ Python Implementation of Linear Regression in Machine Learning + Feature Engineering + Multi Model Comparison (Real-World Dataset)**
# We'll use a **Kaggle dataset for house price prediction** using **Multiple Linear Regression**.
# In ML, we use **libraries like Scikit-Learn** to implement Linear Regression.
#
# ### **Steps for Model Building**
# 1️⃣ Data Preprocessing (handling missing values, scaling)
#
# 2️⃣ Feature Engineering (creating meaningful features)
#
# 3️⃣ Train-Test Split
#
# 4️⃣ Multi Model Training
#
# 5️⃣ Model Evaluation (R², RMSE, MAE)

# %% [markdown]
# ## **Step 1️⃣: Import Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from xgboost import XGBRegressor
from sklearn.impute import KNNImputer
# import statsmodels.api as sm
# from statsmodels.stats.outliers_influence import variance_inflation_factor
# from scipy import stats
# from scipy.stats import shapiro, probplot
# from statsmodels.stats.diagnostic import het_breuschpagan
# from statsmodels.stats.stattools import durbin_watson

# Load the Dataset
df = pd.read_csv('/kaggle/input/california-housing-prices/housing.csv')

# View the Dataset
df.head()

# %% [markdown]
# ## **Step 2️⃣: Loading the Data, Data Exploring, Feature Engineering and Data Preprocessing**
#
# Above we see "ocean_proximity" is the only non numerical column, on which we will do a onehotencoder feature engineering technique, but before that let's see if there is any missing values!

# %%
# Let's check the distribution of the dataset
df.describe()

# %%
# Let's check the datatype and shape of the dataset
df.info()

# %%
#Checking Missing Values and the % if exists
missing_values = df.isnull().sum()  # Count missing values
total_values = len(df)  # Total number of rows
missing_percentage = round(((missing_values / total_values) * 100),2) # Calculate percentage

# Create a result DataFrame
missing_df = pd.DataFrame({
    "Missing Values": missing_values,
    "Percentage (%)": missing_percentage})

missing_df

# %%
#BONUS!
#If the missing values are more thna 5% well we can use imputation methods like
#KNN Imputer, Simple Imputer etc...

# Select only the column with missing values
# total_bedrooms = df[['total_bedrooms']]

# Apply KNN Imputer (k=5)
# knn_imputer = KNNImputer(n_neighbors=6, weights="uniform")
# df[['total_bedrooms']] = knn_imputer.fit_transform(total_bedrooms)

# %%
# Handle missing values
# Since the  Null Values are Less than <3% we drop themm.
df = df.dropna(ignore_index=True)
df.head()

# from sklearn.preprocessing import LabelEncoder
# label_encoder = LabelEncoder()
# df['ocean_proximity']= label_encoder.fit_transform(df['ocean_proximity'])

# Convert categorical feature 'ocean_proximity' to numerical
df = pd.get_dummies(df, drop_first=True,dtype=int)

# %% [markdown]
# ## **Step 3️⃣: Data Visualization and Assumptions Checks**

# %%
# Checking the Visual Data Distribution
df.hist(figsize=(12, 10), bins=30, edgecolor="black")
plt.subplots_adjust(hspace=0.7, wspace=0.4)

# %%
#DATA VISUALIZATION
# Distribution of SalePrice
plt.figure(figsize=(6, 3))
sns.histplot(df['median_house_value'], kde=True)
plt.title('Distribution of SalePrice')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(round(df.corr(),2), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Since, the Correlation is High in total bedrooms we can remove the column,
# as the total rooms column already has the total bedrooms count!

df.drop(columns=["total_bedrooms"],inplace=True)

# %% [markdown]
# ## **Step 3️⃣: Data Preprocessing & Data Split for ML Models**

# %%
# Define features & target

X = df.drop(columns=["median_house_value"])
y = df["median_house_value"]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Fit linear regression model
model = LinearRegression()
model.fit(X_train_scaled, y_train)

# Predictions
y_pred = model.predict(X_test_scaled)

# Residuals
residuals = y_test - y_pred

# %% [markdown]
# ## **Step 4️⃣: Model Training and Evaluation**
#
# #### We will train and evaluate several linear regression models.
#
# #### **1. Multiple Linear Regression Model**
# #### **2. Lasso Regression Model**
# #### **3. Ridge Regression Model**
# #### **4. ElasticNet Model**
# #### **5. XGBoost Regressor Model**

# %%
# 1. Multiple Linear Regression
print('1. Multiple Linear Regression')
# Multiple Linear Regression (using all features)
multiple_model = LinearRegression()
multiple_model.fit(X_train, y_train)
# Predict and evaluate
y_pred_multiple = multiple_model.predict(X_test)
mae_multiple = mean_absolute_error(y_test, y_pred_multiple)
rmse_multiple = np.sqrt(mean_squared_error(y_test, y_pred_multiple))
r2_multiple = round(r2_score(y_test, y_pred_multiple),2)
print(f"Multiple Linear Regression - MAE: {mae_multiple}, RMSE: {rmse_multiple}, R2: {r2_multiple}")
print('')


# 2. Ridge Regression
print('2. Ridge Regression')
# Ridge Regression (with alpha=1.0)
ridge_model = Ridge(alpha=1.2)
ridge_model.fit(X_train, y_train)
# Predict and evaluate
y_pred_ridge = ridge_model.predict(X_test)
mae_ridge = mean_absolute_error(y_test, y_pred_ridge)
rmse_ridge = np.sqrt(mean_squared_error(y_test, y_pred_ridge))
r2_ridge = round(r2_score(y_test, y_pred_ridge),2)
print(f"Ridge Regression - MAE: {mae_ridge}, RMSE: {rmse_ridge}, R2: {r2_ridge}")
print('')



# 3. Lasso Regression
print('3. Lasso Regression')
# Lasso Regression (with alpha=0.1)
lasso_model = Lasso(alpha=0.1)
lasso_model.fit(X_train, y_train)
# Predict and evaluate
y_pred_lasso = lasso_model.predict(X_test)
mae_lasso = mean_absolute_error(y_test, y_pred_lasso)
rmse_lasso = np.sqrt(mean_squared_error(y_test, y_pred_lasso))
r2_lasso = round(r2_score(y_test, y_pred_lasso),2)
print(f"Lasso Regression - MAE: {mae_lasso}, RMSE: {rmse_lasso}, R2: {r2_lasso}")
print('')


# 4. ElasticNet Regression
print('4. ElasticNet Regression')
# ElasticNet Regression (with alpha=0.1 and l1_ratio=0.5)
elasticnet_model = ElasticNet(alpha=0.1, l1_ratio=0.5)
elasticnet_model.fit(X_train, y_train)
# Predict and evaluate
y_pred_elasticnet = elasticnet_model.predict(X_test)
mae_elasticnet = mean_absolute_error(y_test, y_pred_elasticnet)
rmse_elasticnet = np.sqrt(mean_squared_error(y_test, y_pred_elasticnet))
r2_elasticnet = r2_score(y_test, y_pred_elasticnet)
print(f"ElasticNet Regression - MAE: {mae_elasticnet}, RMSE: {rmse_elasticnet}, R2: {r2_elasticnet}")
print(' ')



# 5. Lasso Regression
print('5.Extreme Gradient Boosting Based Ensemble Model - XGBoost Regressor')
xgb = XGBRegressor(n_estimators=700, learning_rate=0.07, max_depth=6)
xgb.fit(X_train, y_train)
# Predict and evaluate
y_pred_xgb = xgb.predict(X_test)
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))
r2_xgb = (r2_score(y_test, y_pred_xgb))
print(f"XGBoost Regressor - MAE: {mae_xgb}, RMSE: {rmse_xgb}, R2: {r2_xgb}")
print(' ')

# %% [markdown]
# ## **Step 5️⃣: Model Comparisons**

# %%
# Create a DataFrame to compare performance metrics
model_comparison = pd.DataFrame({
    'Model': ['Multiple Linear', 'Ridge', 'Lasso', 'ElasticNet','XGBoost Regressor'],
    'MAE': [mae_multiple, mae_ridge, mae_lasso, mae_elasticnet,mae_xgb],
    'RMSE': [rmse_multiple, rmse_ridge, rmse_lasso, rmse_elasticnet,rmse_xgb],
    'R2': [r2_multiple, r2_ridge, r2_lasso, r2_elasticnet,r2_xgb]
})

# Sort by R2
model_comparison.sort_values(by='R2', ascending=False, inplace=True)

model_comparison

# %% [markdown]
# ## **📊 Model Performance Insights**
#
# 🔹 **XGBoost Regressor** achieved the **highest $ R^2 $ score of 84%**, meaning the model explains **84% of the variance** in the target variable using the given feature variables.
#
# ---

# %% [markdown]
# ### *Thanks for Reading !*KRITIKA INWATI
